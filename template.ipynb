# %% [markdown]
# <a href="https://colab.research.google.com/github/ptliam-tech/test-colab/blob/main/template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
revenue = 10000
tax = 0.19
income = revenue * tax
income
# Out:
# 1900.0

# %%
print(income)
# Out:
# 1900.0

# %% [markdown]
# ### Sumary

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'

# %%
np.random.rand?

# %%
import imageai
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_267/4168674327.py in <cell line: 0>()
# ----> 1 import imageai
#
# ModuleNotFoundError: No module named 'imageai'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install imageai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 6.4 MB/s eta 0:00:00
# ...

# %%
import imageai

# %% [markdown]
# ### Markdown
